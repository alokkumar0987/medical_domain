# %%
# %pip install ipykernel

# %%
# %pip install pandas openpyxl

# %%
import pandas as pd
import pandas as pd

pd.set_option('display.max_columns', None)
path = r"D:\project\medical_3Dmodel\test_data\LIDC-IDRI-0001_digest.xlsx"

df = pd.read_excel(path)

print(df.head())
# Out:
#        Patient ID  Patient Name  Patient Birth Date  Patient Sex  \
# 0  LIDC-IDRI-0001           NaN                 NaN          NaN
# 1  LIDC-IDRI-0001           NaN                 NaN          NaN
#
#    Ethnic Group Phantom  Species Code Species Description  \
# 0           NaN      NO     337915000        Homo sapiens
# 1           NaN      NO     337915000        Homo sapiens
#
#                                   Study Instance UID             Study Date  \
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.175012972118...  2000-01-01 00:00:00.0
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.298806137288...  2000-01-01 00:00:00.0
#
#    Study Description  Admitting Diagnosis Description  Study ID  Patient Age  \
# 0                NaN                              NaN       NaN          NaN
# 1                NaN                              NaN       NaN          NaN
#
#    Longitudinal Temporal Event Type  Longitudinal Temporal Offset From Event  \
# ...

# %%
ct_series = df[df["Image Count"] > 10]

print(ct_series[["Patient ID","Image Count"]].head())
# Out:
#        Patient ID  Image Count
# 1  LIDC-IDRI-0001          133

# %%
print(df.columns)
# Out:
# Index(['Patient ID', 'Patient Name', 'Patient Birth Date', 'Patient Sex',
#        'Ethnic Group', 'Phantom', 'Species Code', 'Species Description',
#        'Study Instance UID', 'Study Date', 'Study Description',
#        'Admitting Diagnosis Description', 'Study ID', 'Patient Age',
#        'Longitudinal Temporal Event Type',
#        'Longitudinal Temporal Offset From Event', 'Series Instance UID',
#        'Project', 'Modality', 'Protocol Name', 'Series Date',
#        'Series Description', 'Body Part Examined', 'Series Number',
#        'Annotations Flag', 'Manufacturer', 'Manufacturer Model Name',
#        'Software Versions', 'Image Count', 'Max Submission Timestamp',
#        'License Name', 'License URI', 'Collection URI', 'File Size',
#        'Date Released', 'Third Party Analysis'],
#       dtype='str')

# %%
columns = [
    "Patient ID",
    "Study Instance UID",
    "Series Instance UID",
    "Modality",
    "Series Description",
    "Body Part Examined",
    "Image Count"
]
